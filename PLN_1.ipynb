# %% [markdown]
# <a href="https://colab.research.google.com/github/m-ony/mineria-de-datos/blob/main/PLN_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Monica Hernandez Quiroz 181619

# %%
# Tokenizar con NLTK

import nltk
### Qué hace? Esta parte importa la biblioteca NLTK (Natural Language Toolkit), que es un conjunto de herramienta usado para procesamiento de lenguaje natural (NLP).

nltk.download('punkt_tab')  # Download the necessary resources
### Qué hace? Esta linea descargar el paquete punkt, que es necesario para realizar tareas de análisis sintáctico.

from nltk.tokenize import word_tokenize
### Qué hace? Esta linea significa que se importando la función word_tokenize del módulo nltk.tokenize de la librería NLTK (Natural Language Toolkit), la cual servira para
### segmentar texto en palabras y signos de puntuación
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
# Texto de ejemplo
text = "Natural Language Processing (NLP) enables machines to understand human language."

# %%
# Tokeniza el texto
tokens = word_tokenize(text)
# Imprime tokens
print (tokens)


### Buscar tokenizador para español y hacer un ejemplo
#Se puede utilizar
# - split() útil cuando el texto es simple y no contiene signos de puntuación complejos o caracteres especiales que requieran un manejo específico, se guia por os espacios.
# - word_tokenize() permite dividir un texto en palabras y signos de puntuación, tratándolos como tokens independientes. Esto es especialmente útil cuando los signos
    #de puntuación, como comas o apóstrofes, son importantes para el análisis, ya que pueden alterar el significado del texto.
# - re.findall() Tokenización con expresiones regulares, es particularmente poderosa, ya que te permite especificar exactamente qué tipo de tokens deseas extraer,
    #como palabras, números o incluso patrones más complejos como direcciones de correo electrónico o hashtags.


# Ejemplo
text2 = "Los chatbots son útiles"
tokens2 = text2.split()
print (tokens2)

text3 = "¿Cuánto tiempo es para siempre? A veces solo un segundo."
tokens3 = word_tokenize(text3)
print (tokens3)
# Out:
# ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'enables', 'machines', 'to', 'understand', 'human', 'language', '.']
# ['Los', 'chatbots', 'son', 'útiles']
# ['¿Cuánto', 'tiempo', 'es', 'para', 'siempre', '?', 'A', 'veces', 'solo', 'un', 'segundo', '.']

# %%
#Traducción
# !pip install translate
### Qué hace? En esta linea de codigo primero indica que va ejecutar en un entorno como Google Colab y que debe instalar
#la libreria translate. Esa librería permite traducir texto entre diferentes idiomas usando APIs o motores de traducción.

from translate import Translator
### Qué hace? En esta linea se importa la clse Translator de la libreira translate que se intalo en linea anterior.
#Esa clase es la que te permite crear un objeto traductor para convertir texto de un idioma a otro.

# Create a translator object
translator = Translator(to_lang="es")
### Qué hace? Estás creando un objeto traductor que va a convertir texto a español, to_lang="es" indica el idioma al cual va traducir en este caso español

# Translate a phrase
translation = translator.translate("How are you?")
print(translation)  # Output: ¿Cómo estás?
# Out:
# ...
# ¿Cómo estás?

# %%
# Análisis de sentimientos

from textblob import TextBlob
### Qué hace? Se esta importando la clase TextBlob de la libreria textblob, esta es una librería de procesamiento de lenguaje natural (NLP)
# que facilita el analisis de sentimiento, correcciones ortográficas, etc.

# Sample text
text = "I love this product! It's amazing."

# Create a TextBlob object
blob = TextBlob(text)
### Qué hace? Crea el objeto TextBlod apartir dde la variable text que contiene el texto para el analisis.
#Ese objeto encapsula el texto y te da acceso a varias funciones de procesamiento de lenguaje natural (PLN).

# Perform sentiment analysis
sentiment = blob.sentiment
print(sentiment)  # Output: Sentiment(polarity=0.65, subjectivity=0.6)

### Qué significa la salida? La polaridad significa que debajo de 0 toma un tono negativo y arriba de 0 toma un tono mas positivo que es lo que pasa en este caso,
# mientras tanto subjetividad arroja valores entre 0 (objetivo) y 1 (subjetivo).

### Textblob no tiene análisis de sentimientos es español
### ¿Cómo solucionarlo?
#Se podria tener el texto en español despues con translate poder cambiar alm idioma ingles y despues aplicar textblod.
### Impleméntalo con un ejemplo en español

#Declaramos la frase
frase="¡Estoy muy feliz!, Pronto es mi cumpleaños."
#Objeto traductor al ingles
translator_english= Translator(to_lang="en")
#Aplicamos la traducción al ingles
fraseTraducida=translator_english.translate(frase)
print(fraseTraducida)
#creamos el objeto Textblod y aplicamos sentiment
blob = TextBlob(fraseTraducida)
sentiment = blob.sentiment
print(sentiment)
# Out:
# Sentiment(polarity=0.6125, subjectivity=0.75)
# I'm so happy! It's my birthday soon.
# Sentiment(polarity=1.0, subjectivity=1.0)

# %%
# Resumen de texto
# !pip install sumy

from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer

### Qué hacen las funciones anteriores?
#Todas la lineas anteriores estan importanto paquetes de la libreria Sumy, la primera convierte un texto a una estructura que
#sumy pueda entender, el segundo se encarga de tokenizar el texto, es decir dividirlo en oraciones o palabras. El tercer permite genrar un resumen
#automático, analizando las relaciones semánticas entre las palabras y frases del texto.


# Sample text
text = """
Natural Language Processing (NLP) is a fascinating field.
 at the intersection of computer science,
 artificial intelligence, and linguistics.
  It enables machines to understand, interpret,
   and generate human language.
    opening up a world of possibilities. That use for applications ranging from chatbots and translation services to sentiment analysis and beyond.
"""

# Create a parser
parser = PlaintextParser.from_string(text, Tokenizer("english"))

# Create a summarizer
summarizer = LsaSummarizer()

# Generate the summary
summary = summarizer(parser.document, 2)  # Summarize to 2 sentences
for sentence in summary:
    print(sentence)


### Investigar la opción para español y hacer un ejemplo
# Para hacer una versión  en español se debe cambiar el idioma en este linea parser = PlaintextParser.from_string(text, Tokenizer("english"))

text2="""
Una niña pasaba todas las mañanas frente a un jardín lleno de flores de todos los colores. Siempre quería llevarse una flor a la escuela, así que cada día arrancaba una.
Con el tiempo, notó que las flores que tomaba se marchitaban rápidamente y que el jardín empezaba a quedarse vacío.
Al darse cuenta de que estaba acabando con la belleza del lugar, decidió dejar de arrancar flores y admirarlas desde lejos.
Desde entonces, el jardín volvió a florecer y la niña aprendió a respetar la vida y la naturaleza.
"""
parser2 = PlaintextParser.from_string(text2, Tokenizer("spanish"))

# Create a summarizer
summarizer2 = LsaSummarizer()

# Generate the summary
summary2 = summarizer2(parser2.document, 2)  # Summarize to 2 sentences
for sentence in summary2:
    print(sentence)
# Out:
# ...
# at the intersection of computer science, artificial intelligence, and linguistics.
# It enables machines to understand, interpret, and generate human language.
# Una niña pasaba todas las mañanas frente a un jardín lleno de flores de todos los colores.
# Al darse cuenta de que estaba acabando con la belleza del lugar, decidió dejar de arrancar flores y admirarlas desde lejos.

# %%
## Analizar reseñas

import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
### Qué hace?
# Primer linea se esta importando la libreria nltlk que es un conjunto de herramientas para procesamiento de lenguaje natural.
# En la segunda linea se importa el analizador de sentimientos VADER, que es un modelo entrenado especialmente para analizar sentimientos en textos cortos e informales.

# Sample reviews
reviews = [
    "This product is fantastic! It exceeded my expectations.",
    "Not worth the price. I'm disappointed with the quality.",
    "Good value for money. Will buy again.",
]

# Initialize the sentiment analyzer
nltk.download('vader_lexicon')
### Qué hace vader_lexicon? Es un diccionario de sentimientos, es la base de datos que le da a VADER la capacidad de reconocer palabras y calcular el sentimiento de un texto.

sia = SentimentIntensityAnalyzer()

# Analyze each review
for review in reviews:
    sentiment = sia.polarity_scores(review)
    print(f"Review: {review}\\nSentiment: {sentiment}\\n")

### Qué significado tienen las salidas?
# neg es negativo el texto
# neu es neutral el texto
# pos es positivo el texto
# la suma de los tres anterios debe ser 1
# compound es el puntaje global

#En este caso no hay algo negativo en el texto, esta un 48% neutro y 51% positivo.
# Out:
# Review: This product is fantastic! It exceeded my expectations.\nSentiment: {'neg': 0.0, 'neu': 0.643, 'pos': 0.357, 'compound': 0.5983}\n
# Review: Not worth the price. I'm disappointed with the quality.\nSentiment: {'neg': 0.405, 'neu': 0.595, 'pos': 0.0, 'compound': -0.5812}\n
# Review: Good value for money. Will buy again.\nSentiment: {'neg': 0.0, 'neu': 0.485, 'pos': 0.515, 'compound': 0.6486}\n
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
# !python -m spacy download es_core_news_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 48.6 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# Reconocer entidades (E2)
import spacy
### Qué hace la bilbioteca spacy?
# Permite dividir textos en palabras y oraciones, identificar categorías gramaticales,
#convertir palabras a su forma base, reconocer entidades como personas o lugares, analizar relaciones sintácticas,
#clasificar documentos, trabajar en múltiples idiomas y conectarse con frameworks de deep learning, todo con gran velocidad y eficiencia para proyectos reales.

# Load SpaCy model
nlp = spacy.load("en_core_web_sm")

### Qué hace? se esta cargando un modelo de lenguaje en ingles

text = "Google was founded by Larry Page and Sergey Brin while they were Ph.D. students at Stanford University."
doc = nlp(text)

# Extract named entities
for ent in doc.ents:
    print(ent.text, ent.label_)

print("\n-----------------\n")
### Investiga si hay spacy para español.
  #Si hay solo se necesita cargar el modelo de lenguaje en español con es_core_news_sm
### Realiza un ejemplo en español para reconocer entidades
### también aplícalo para realizar la lematización (raíces) de las palabras
### y obtener el análisis morfológico

text2 = "En 2022, Elon Musk adquirió Twitter por 44 mil millones de dólares. La transacción fue analizada en Nueva York por la Comisión de Valores de Estados Unidos. Mientras tanto, en Madrid, la Universidad Complutense organizó un congreso sobre inteligencia artificial con expertos de Google y Microsoft"
nlp2 = spacy.load("es_core_news_sm")
doc2 = nlp2(text2)

# Entidades
for ent in doc2.ents:
    print(ent.text, ent.label_)
#lematización
print("\n-----------------\n")
for token in doc2:
    print(token.text, token.lemma_)

#Análisis morfológico
print("\n-----------------\n")
for token in doc2:{
    print(token.text, token.pos_, token.morph)
}
# Out:
# Google ORG
# Larry Page PERSON
# Sergey Brin PERSON
# Ph.D. WORK_OF_ART
# Stanford University ORG
#
# -----------------
#
# Elon Musk PER
# Twitter MISC
# La transacción MISC
# Nueva York LOC
# Comisión de Valores de Estados Unidos ORG
# Madrid LOC
# Universidad Complutense ORG
# Google ORG
# Microsoft ORG
#
# -----------------
#
# En en
# 2022 2022
# , ,
# Elon Elon
# Musk Musk
# adquirió adquirir
# Twitter Twitter
# por por
# 44 44
# mil mil
# millones millón
# de de
# dólares dólares
# . .
# La el
# transacción transacción
# fue ser
# analizada analizar
# en en
# Nueva Nueva
# York York
# por por
# la el
# Comisión Comisión
# de de
# Valores Valores
# de de
# Estados Estados
# Unidos Unidos
# . .
# Mientras mientras
# tanto tanto
# , ,
# en en
# Madrid Madrid
# , ,
# la el
# Universidad Universidad
# Complutense Complutense
# organizó organizar
# un uno
# congreso congreso
# sobre sobre
# inteligencia inteligencia
# artificial artificial
# con con
# expertos experto
# de de
# ...

# %%
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 25.7 MB/s eta 0:00:00
# ...

# %%
# Similitud de documentos
from gensim.models import Word2Vec
### Qué hace gensim?
  # Es una biblioteca popular de procesamiento de lenguaje natural (NLP) de código abierto que se utiliza para el modelado de temas sin supervisión.
    # Construcción de vectores de documento o palabra
    # Corpora
    # Realizar identificación de temas
    # Realizar comparación de documentos (recuperar documentos semánticamente similares)
    # Análisis de documentos de texto sin formato para estructura semántica
### Qué hace Word2Vec ? Utilizado para producir incrustaciones de palabras, es un grupo de modelos de redes neuronales superficiales y de dos capas.
    # Los modelos están básicamente entrenados para reconstruir contextos lingüísticos de palabras.

# Sample sentences
sentences = [
    ["natural", "language", "processing"],
    ["python", "is", "a", "powerful", "language"],
    ["text", "processing", "with", "gensim"],
]

# Train Word2Vec model
model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=4)
### qué significado tienen los parámetros utilizados?
    # sentences es conjunto de oraciones que se utilizarán para entrenar el modelo.
    # vector_size Dimensión del vector que representará cada palabra. Cuanto mayor sea, más información semántica puede capturar, pero también requiere más datos y tiempo de entrenamiento.
    # window El modelo considera hasta n palabras alrededor de la palabra que está aprendiendo.
    # min_count Frecuencia mínima para incluir una palabra en el vocabulario. Si una palabra aparece menos veces que este valor, se descarta.
    # workers Número de hilos de CPU usados en paralelo para entrenar.

# Get vector for a word
vector = model.wv['language']
print(vector)


### Qué diferencias y similitudes tiene Word2Vec con gensim?
# Gensim es mas flexible ya que ofrece soporte para otros algoritmos y técnicas de análisis de texto , Word2Vec en comparación, está diseñado exclusivamente para generar representaciones vectoriales basadas en palabras
# Dentro de escalabilidad gensim es otimizado para grandes datasets, mientras que Word2Vec es limitado por memoria disponible.
# Curva de aprendizaje en gensim es más compleja debido a múltiples funcionalidades	y Word2Vec es mucho mas fácil de implementar.
# Out:
# [-8.6196875e-03  3.6657380e-03  5.1898835e-03  5.7419385e-03
#   7.4669183e-03 -6.1676754e-03  1.1056137e-03  6.0472824e-03
#  -2.8400505e-03 -6.1735227e-03 -4.1022300e-04 -8.3689485e-03
#  -5.6000124e-03  7.1045388e-03  3.3525396e-03  7.2256695e-03
#   6.8002474e-03  7.5307419e-03 -3.7891543e-03 -5.6180597e-04
#   2.3483764e-03 -4.5190323e-03  8.3887316e-03 -9.8581640e-03
#   6.7646410e-03  2.9144168e-03 -4.9328315e-03  4.3981876e-03
#  -1.7395747e-03  6.7113843e-03  9.9648498e-03 -4.3624435e-03
#  -5.9933780e-04 -5.6956373e-03  3.8508223e-03  2.7866268e-03
#   6.8910765e-03  6.1010956e-03  9.5384968e-03  9.2734173e-03
#   7.8980681e-03 -6.9895042e-03 -9.1558648e-03 -3.5575271e-04
#  -3.0998408e-03  7.8943167e-03  5.9385742e-03 -1.5456629e-03
#   1.5109634e-03  1.7900408e-03  7.8175711e-03 -9.5101865e-03
#  -2.0553112e-04  3.4691966e-03 -9.3897223e-04  8.3817719e-03
#   9.0107834e-03  6.5365066e-03 -7.1162102e-04  7.7104042e-03
# ...

# %%
# Clasificación con scikit-learn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

### Qué es scikit-learn? Es una bibloteca den Python para el aprendizaje automático. Es de código abierto y ofrece una amplia gama de herramientas para tareas como clasificación, regresión, agrupamiento y reducción de dimensionalidad.
### Qué hace CountVectorizer?  Tiene varias funciones clave que facilitan la conversión de texto en características numéricas como:
    # Crea automáticamente un vocabulario a partir de los documentos de entrada, asignando índices únicos a cada token.
    # Permite el preprocesamiento de datos de texto antes de generar la representación vectorial, lo que es útil para aplicar reglas con respecto al número y frecuencia de tokens.
    # Utiliza un modelo de bag-of-words para codificar el texto, asignando un peso a cada token proporcional a la frecuencia con la que aparece en el documento y/o corpus.
    # Crea una matriz donde cada fila representa un documento y cada columna se dirige a un token, facilitando la representación numérica del texto.
### y MultinomialNB?
    # Este clasificador está diseñado específicamente para trabajar con características que representan recuentos o frecuencias de eventos discretos.
    # Lo que hace es clasificar texto (u otros datos discretos) usando el modelo probabilístico Naive Bayes.
    # Calcula la probabilidad de que un documento pertenezca a una clase según las palabras que contiene.

# Sample data
texts = ["I love this product", "This is the worst experience", "Absolutely fantastic!", "Not good at all", "I hate this", "I dislike it"]
labels = [1, 0, 1, 0, 0, 0]

# Vectorize text data
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(texts)

### Qué hace? Primero inicializa el objeto (vectorizer) crear un vocabulario con las palabras encontradas
    # fit.transform hace un análisis y aprende del vocabulario. Después convierte cada texto en números según cuántas veces aparece cada palabra.

# Train a Naive Bayes classifier
classifier = MultinomialNB()
classifier.fit(X, labels)

### Qué hace fit? Entrena el clasificador Naive Bayes recibe x que son la matriz de caracteristicas y labels las clases objetivo.
                  # Se guarda esos parametros en classifier para despues aplicar .predict().

# Predict sentiment for a new text
new_text = ["I hate this"]
X_new = vectorizer.transform(new_text)
prediction = classifier.predict(X_new)
print(prediction)

### Qué significado tiene el resultado?
# Frase positiva [1] o negativa [0]
# El resultado significa que el modelo predijo correctamente que la frase era negativa por eso lanzo como resultado 0.
# Out:
# [0]

# %%
# Resumen con sumy (E4)

# !pip install sumy

from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer

text = """
Natural Language Processing (NLP) is a fascinating field at the intersection of computer science, artificial intelligence, and linguistics. It enables machines to understand, interpret, and generate human language, opening up a world of possibilities for applications ranging from chatbots and translation services to sentiment analysis and beyond. The evolution of NLP has been driven by significant advances in machine learning and deep learning, which have enabled more sophisticated and accurate models for language understanding. This book aims to bring these cutting-edge techniques to you in an accessible and practical way, regardless of your current level of expertise.
"""

parser = PlaintextParser.from_string(text, Tokenizer("english"))
summarizer = LsaSummarizer()
summary = summarizer(parser.document, 2)
for sentence in summary:
    print(sentence)
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 67.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 41.2 MB/s eta 0:00:00
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=0b1df812c06b0c60874d75ffd09da80ae5075cfba86cdc57cf5f07a9f688f978
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built docopt
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# ...
